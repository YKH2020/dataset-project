# %%
import pandas as pd
import chardet
from pandasgui import show
from sklearn.preprocessing import LabelEncoder

# %% [markdown]
# ### __Survey Data__

# %%
responses_df = pd.read_csv('./data/responses.csv')

# %%
def encode_column_names(columns):
    encoded_mapping = {}

    # Encode the first 18 columns as SQ1 to SQ18
    for i in range(1, 19):
        encoded_mapping[f"SQ{i}"] = columns[i]

    # Encode the next 5 columns as BQ1 to BQ5
    for i, col in enumerate(columns[19:24], start=1):
        encoded_mapping[f"BQ{i}"] = col

    # Encode the next 5 columns as DQ1 to DQ5
    for i, col in enumerate(columns[24:29], start=1):
        encoded_mapping[f"DQ{i}"] = col

    # Encode the last 5 columns as MQ1 to MQ5
    for i, col in enumerate(columns[29:], start=1):
        encoded_mapping[f"MQ{i}"] = col

    return encoded_mapping

# %%
# Get the original column names and generate the mapping
original_columns = responses_df.columns.tolist()
encoded_mapping = encode_column_names(original_columns)

# Rename columns in the DataFrame
responses_df.rename(columns={v: k for k, v in encoded_mapping.items()}, inplace=True)

# Step 2: Fill Missing Values
responses_df.fillna('Not Taken', inplace=True)

# Step 3: Encode Student IDs in 'SQ1'
label_encoder = LabelEncoder()
responses_df['SQ1'] = label_encoder.fit_transform(responses_df['SQ1'])
responses_df.rename(columns={'SQ1': 'SQ1_encoded'}, inplace=True)

# Save mapping for later use
id_mapping = dict(zip(label_encoder.classes_, label_encoder.transform(label_encoder.classes_)))

# %%
replacement_map = {
    'ARTIFICIAL INTELLIGENCE IN PRODUCT INNOVATION': 'AIPI',
    'ARTIFICIAL INTELLIGENCE': 'AIPI',
    'AI': 'AIPI',
    'M.ENG AIPI': 'AIPI',
    'MENG IN AIPI': 'AIPI',
    'COMPUTER SCIENCE, PHYSICS': 'CS & PHYSICS',
    'PHYSICS, COMPUTER SCIENCE': 'CS & PHYSICS',
    'ECONOMIC S': 'ECON',
    'UNDECLARED - STATISTICAL SCIENCE': 'UNDECLARED/STATSCI',
    'LINGUISTICS AND SPANISH': 'LINGUISTICS & SPANISH',
    'MECHANICAL ENGINEERING': 'MECHE',
    'FGG': 'UNDECLARED'
}

# Normalize 'SQ2' and apply replacements
responses_df['SQ2'] = (
    responses_df['SQ2']
    .str.strip()
    .str.upper()
    .replace(replacement_map)
)

print("\nMapping of Encoded Column Names:")
print(encoded_mapping)

print("\nMapping of Original IDs to Encoded Values:")
print(id_mapping)
# Out:
# Mapping of Encoded Column Names:
# {'SQ1': "What's your Duke Student ID?\n(Leave blank if not a Duke student)", 'SQ2': "What's your major?", 'SQ3': 'Are you an AIPI Student at Duke?', 'SQ4': 'Are you an Undergraduate or Graduate Student?', 'SQ5': 'Study Time Spent per day in Hours?', 'SQ6': 'How much do you feel you have participated in class?', 'SQ7': 'How much do you feel you use what you have learned outside of class?', 'SQ8': 'How comfortable are you with using generative AI tools like ChatGPT to assist with your learning?  ', 'SQ9': 'In which aspects of your learning have you used generative AI tools?', 'SQ10': 'How frequently do you use generative AI tools for learning-related tasks?', 'SQ11': 'To what extent do you feel generative AI has improved your academic performance?  ', 'SQ12': 'What concerns, if any, do you have about using generative AI in your learning process?  ', 'SQ13': 'How would you rate your overall academic performance in the past few weeks of the semester?', 'SQ14': 'How have your grades in assignments changed as the semester has progressed?  ', 'SQ15': 'How closely do your current grades align with your expectations?  ', 'SQ16': 'Have you noticed any specific trends in your grades across different subjects throughout the semester?  ', 'SQ17': 'How much do you believe your study habits or external factors have influenced your grades this semester?  ', 'SQ18': 'If you are an AIPI student, indicate which class you feel you understand the most. (If you are not an AIPI student and have taken any of the following courses, indicate which one you feel you understand the most), otherwise choose N/A. ', 'BQ1': 'In the Lean Canvas, what is the purpose of the Unique Value Proposition (UVP)?  ', 'BQ2': 'What is the main role of early adopters in the Lean Start-Up approach?  ', 'BQ3': 'What does market segmentation help a business achieve?  ', 'BQ4': 'According to the Lean Canvas, what is an "Unfair Advantage"?  ', 'BQ5': 'What does "customer discovery" aim to achieve in the Lean Start-Up process?  ', 'DQ1': 'What is the primary purpose of sourcing data for analytics?  ', 'DQ2': 'Which of the following is a key challenge when sourcing data from external sources?  ', 'DQ3': 'What is a common reason for using APIs in data sourcing?  ', 'DQ4': 'What is one advantage of using web scraping to source data for analytics?  ', 'DQ5': 'Which type of data source is best suited for real-time analytics?  ', 'MQ1': "What does the 'no free lunch theorem' imply when it comes to algorithm selection?  ", 'MQ2': 'Which of the following is NOT a key assumption in linear regression models?  ', 'MQ3': "In a residual plot, what does a 'hill-shaped' pattern of residuals indicate?  ", 'MQ4': 'When constructing a confidence interval, what does a 95% confidence level mean?  ', 'MQ5': 'Which of the following is a common reason why a model might underfit the data?  '}
#
# Mapping of Original IDs to Encoded Values:
# {'2473536': 0, '2636294': 1, '2959994': 2, '2967263': 3, '3037834': 4, '3049113': 5, '3051733': 6, '3051747': 7, 'AC946': 8, 'Cfg': 9, 'Dgt647': 10, 'Fgy466': 11, 'Gu644': 12, 'Isr9': 13, 'Lfa10': 14, 'Sc967': 15, 'Vt81': 16, 'ab1107': 17, 'al625': 18, 'ap765': 19, 'ckc34': 20, 'hc403': 21, 'hl535': 22, 'lw416': 23, 'mj324': 24, 'ok61': 25, 'skb79': 26, 'skv18 ': 27, 'sp739': 28, 'tj152': 29}

# %%
responses_df
# Out:
#               Timestamp  SQ1_encoded                    SQ2  SQ3  \
# 0   10/15/2024 18:09:15            1                   AIPI  Yes
# 1    10/19/2024 9:28:01           28                   AIPI  Yes
# 2    10/19/2024 9:34:52           15               BUSINESS   No
# 3    10/19/2024 9:49:56            4           CS & PHYSICS  Yes
# 4    10/19/2024 9:54:08            3     UNDECLARED/STATSCI   No
# 5   10/19/2024 10:16:20           21                   AIPI  Yes
# 6   10/19/2024 11:40:50           11                   ECON  Yes
# 7   10/19/2024 23:56:37           25                   AIPI  Yes
# 8   10/20/2024 13:47:36           16                   AIPI  Yes
# 9   10/22/2024 11:36:39            7                   AIPI  Yes
# 10  10/22/2024 11:43:13           14                   AIPI  Yes
# 11  10/22/2024 11:54:54           29                   AIPI  Yes
# 12  10/22/2024 13:28:39           17                   AIPI  Yes
# 13   11/1/2024 18:47:13            9             UNDECLARED  Yes
# 14   11/9/2024 10:52:39           27                   AIPI  Yes
# 15   11/9/2024 10:56:32           20  LINGUISTICS & SPANISH   No
# 16   11/9/2024 11:22:59            2                  MECHE   No
# 17   11/9/2024 12:03:18           10                   ECON  Yes
# 18  11/18/2024 19:20:16           13                   AIPI  Yes
# 19  11/18/2024 19:36:09           12                   ECON  Yes
# 20  11/21/2024 13:46:14           26                   AIPI  Yes
# 21  11/21/2024 17:34:35            5                   AIPI  Yes
# 22  11/21/2024 18:04:37           19                   AIPI  Yes
# 23  11/21/2024 21:14:39           23                   AIPI  Yes
# 24  11/23/2024 13:04:19            4           CS & PHYSICS  Yes
# 25  11/23/2024 16:32:13            0                   AIPI  Yes
# 26  11/23/2024 17:39:01           18                   AIPI  Yes
# 27  11/23/2024 21:08:06            6                   AIPI  Yes
# 28  11/23/2024 21:54:18           24                    ECE   No
# 29  11/24/2024 13:16:21           22                   AIPI  Yes
# 30  11/24/2024 13:50:18            8                   AIPI  Yes
#
#               SQ4    SQ5  SQ6  SQ7  SQ8  \
# 0        Graduate      2    2    3    5
# 1        Graduate      6    2    3    5
# 2        Graduate      3    5    5    5
# 3        Graduate      4    4    5    5
# 4   Undergraduate      2    5    4    5
# 5        Graduate      4    5    4    5
# 6   Undergraduate      6    5    4    4
# 7        Graduate      3    2    2    4
# 8        Graduate      5    3    4    3
# 9        Graduate     15    5    4    5
# 10       Graduate      6    5    5    5
# 11       Graduate      3    3    1    2
# 12       Graduate      8    5    4    5
# 13       Graduate      4    2    3    4
# 14       Graduate      5    5    4    3
# 15  Undergraduate      3    5    4    1
# 16  Undergraduate      2    4    3    1
# 17  Undergraduate      5    5    4    3
# 18       Graduate      4    3    4    3
# 19  Undergraduate      3    3    4    4
# 20       Graduate     12    5    5    2
# 21       Graduate      3    2    2    5
# 22       Graduate    3-4    2    5    5
# 23       Graduate    3.5    3    4    4
# 24       Graduate      3    3    3    5
# 25       Graduate      4    2    3    4
# 26       Graduate    1-2    2    5    5
# 27       Graduate      3    3    3    4
# 28       Graduate  4 hrs    2    3    5
# 29       Graduate   4-12    5    4    5
# 30       Graduate     10    4    5    4
#
#                                                   SQ9  ...  \
# 0   Writing Assignments, General Problem-Solving, ...  ...
# 1   Writing Assignments, Research, General Problem...  ...
# 2   Research, General Problem-Solving, Studying fo...  ...
# 3   Writing Assignments, Research, General Problem...  ...
# 4   Writing Assignments, Research, General Problem...  ...
# 5        Writing Assignments, General Problem-Solving  ...
# 6                   Research, General Problem-Solving  ...
# 7   Writing Assignments, Research, General Problem...  ...
# 8   Research, General Problem-Solving, Studying fo...  ...
# 9   Writing Assignments, General Problem-Solving, ...  ...
# 10  Writing Assignments, General Problem-Solving, ...  ...
# 11  Writing Assignments, Research, General Problem...  ...
# 12  Writing Assignments, Research, General Problem...  ...
# 13                                           Research  ...
# 14                            General Problem-Solving  ...
# 15                                Writing Assignments  ...
# 16  I attempted to use it to help me work out a ma...  ...
# 17        General Problem-Solving, Studying for Exams  ...
# 18                                Writing Assignments  ...
# 19                            General Problem-Solving  ...
# 20  Understanding core concepts and difficult math...  ...
# 21  Writing Assignments, Research, General Problem...  ...
# 22  Writing Assignments, Research, General Problem...  ...
# 23        General Problem-Solving, Studying for Exams  ...
# 24  Writing Assignments, Research, General Problem...  ...
# 25  Writing Assignments, Research, General Problem...  ...
# 26  Writing Assignments, Research, General Problem...  ...
# 27  Writing Assignments, Research, Studying for Exams  ...
# 28        General Problem-Solving, Studying for Exams  ...
# 29  Writing Assignments, General Problem-Solving, ...  ...
# 30  Research, General Problem-Solving, Studying fo...  ...
#
#                                                   DQ1  \
# 0   To collect data from various sources for analy...
# 1                                           Not Taken
# 2                                           Not Taken
# 3   To collect data from various sources for analy...
# 4                                           Not Taken
# 5                                           Not Taken
# 6          To store data securely in a data warehouse
# 7                                           Not Taken
# 8                                           Not Taken
# 9                                           Not Taken
# 10  To collect data from various sources for analy...
# 11                                          Not Taken
# 12                                          Not Taken
# 13      To generate reports based on past performance
# 14  To collect data from various sources for analy...
# 15                                          Not Taken
# 16                                          Not Taken
# 17  To collect data from various sources for analy...
# 18                                          Not Taken
# 19                                          Not Taken
# 20                                          Not Taken
# 21                                          Not Taken
# 22                                          Not Taken
# 23                                          Not Taken
# 24                                          Not Taken
# 25                                          Not Taken
# 26  To collect data from various sources for analy...
# 27                                          Not Taken
# 28                                          Not Taken
# 29                                          Not Taken
# 30                                          Not Taken
#
#                                                   DQ2  \
# 0      Verifying the quality and accuracy of the data
# 1                                           Not Taken
# 2                                           Not Taken
# 3      Verifying the quality and accuracy of the data
# 4                                           Not Taken
# 5                                           Not Taken
# 6      Verifying the quality and accuracy of the data
# 7                                           Not Taken
# 8                                           Not Taken
# 9                                           Not Taken
# 10     Verifying the quality and accuracy of the data
# 11                                          Not Taken
# 12                                          Not Taken
# 13  Using a specific programming language to acces...
# 14     Verifying the quality and accuracy of the data
# 15                                          Not Taken
# 16                                          Not Taken
# 17     Verifying the quality and accuracy of the data
# 18                                          Not Taken
# 19                                          Not Taken
# 20                                          Not Taken
# 21                                          Not Taken
# 22                                          Not Taken
# 23                                          Not Taken
# 24                                          Not Taken
# 25                                          Not Taken
# 26     Verifying the quality and accuracy of the data
# 27                                          Not Taken
# 28                                          Not Taken
# 29                                          Not Taken
# 30                                          Not Taken
#
#                                                   DQ3  \
# 0   To extract real-time data from various online ...
# 1                                           Not Taken
# 2                                           Not Taken
# 3   To extract real-time data from various online ...
# 4                                           Not Taken
# 5                                           Not Taken
# 6               To store data in relational databases
# 7                                           Not Taken
# 8                                           Not Taken
# 9                                           Not Taken
# 10  To extract real-time data from various online ...
# 11                                          Not Taken
# 12                                          Not Taken
# 13          To create complex machine learning models
# 14  To extract real-time data from various online ...
# 15                                          Not Taken
# 16                                          Not Taken
# 17              To store data in relational databases
# 18                                          Not Taken
# 19                                          Not Taken
# 20                                          Not Taken
# 21                                          Not Taken
# 22                                          Not Taken
# 23                                          Not Taken
# 24                                          Not Taken
# 25                                          Not Taken
# 26  To extract real-time data from various online ...
# 27                                          Not Taken
# 28                                          Not Taken
# 29                                          Not Taken
# 30                                          Not Taken
#
#                                                   DQ4  \
# 0   It can extract data from websites without need...
# 1                                           Not Taken
# 2                                           Not Taken
# 3   It can extract data from websites without need...
# 4                                           Not Taken
# 5                                           Not Taken
# 6   It can extract data from websites without need...
# 7                                           Not Taken
# 8                                           Not Taken
# 9                                           Not Taken
# 10  It can extract data from websites without need...
# 11                                          Not Taken
# 12                                          Not Taken
# 13               It ensures 100% accuracy in the data
# 14  It can extract data from websites without need...
# 15                                          Not Taken
# 16                                          Not Taken
# 17               It ensures 100% accuracy in the data
# 18                                          Not Taken
# 19                                          Not Taken
# 20                                          Not Taken
# 21                                          Not Taken
# 22                                          Not Taken
# 23                                          Not Taken
# 24                                          Not Taken
# 25                                          Not Taken
# 26  It can extract data from websites without need...
# 27                                          Not Taken
# 28                                          Not Taken
# 29                                          Not Taken
# 30                                          Not Taken
#
#                          DQ5  \
# 0                 Data lakes
# 1                  Not Taken
# 2                  Not Taken
# 3     Streaming data sources
# 4                  Not Taken
# 5                  Not Taken
# 6                 Data lakes
# 7                  Not Taken
# 8                  Not Taken
# 9                  Not Taken
# 10    Streaming data sources
# 11                 Not Taken
# 12                 Not Taken
# 13  Batch processing systems
# 14                Data lakes
# 15                 Not Taken
# 16                 Not Taken
# 17    Streaming data sources
# 18                 Not Taken
# 19                 Not Taken
# 20                 Not Taken
# 21                 Not Taken
# 22                 Not Taken
# 23                 Not Taken
# 24                 Not Taken
# 25                 Not Taken
# 26    Streaming data sources
# 27                 Not Taken
# 28                 Not Taken
# 29                 Not Taken
# 30                 Not Taken
#
#                                                   MQ1  \
# 0                                           Not Taken
# 1   No single algorithm performs best across all t...
# 2                                           Not Taken
# 3                                           Not Taken
# 4                                           Not Taken
# 5   No single algorithm performs best across all t...
# 6                                           Not Taken
# 7                                           Not Taken
# 8   No single algorithm performs best across all t...
# 9   No single algorithm performs best across all t...
# 10                                          Not Taken
# 11  No single algorithm performs best across all t...
# 12  No single algorithm performs best across all t...
# 13                                          Not Taken
# 14                                          Not Taken
# 15                                          Not Taken
# 16                                          Not Taken
# 17                                          Not Taken
# 18  No single algorithm performs best across all t...
# 19  No single algorithm performs best across all t...
# 20  No single algorithm performs best across all t...
# 21                                          Not Taken
# 22  No single algorithm performs best across all t...
# 23                                          Not Taken
# 24  No single algorithm performs best across all t...
# 25                                          Not Taken
# 26                                          Not Taken
# 27                                          Not Taken
# 28                                          Not Taken
# 29  No single algorithm performs best across all t...
# 30                                          Not Taken
#
#                                                   MQ2  \
# 0                                           Not Taken
# 1   There are significant multicollinearity issues...
# 2                                           Not Taken
# 3                                           Not Taken
# 4                                           Not Taken
# 5   There are significant multicollinearity issues...
# 6                                           Not Taken
# 7                                           Not Taken
# 8   There are significant multicollinearity issues...
# 9   There are significant multicollinearity issues...
# 10                                          Not Taken
# 11  There are significant multicollinearity issues...
# 12  There are significant multicollinearity issues...
# 13                                          Not Taken
# 14                                          Not Taken
# 15                                          Not Taken
# 16                                          Not Taken
# 17                                          Not Taken
# 18  There are significant multicollinearity issues...
# 19  There are significant multicollinearity issues...
# 20  There are significant multicollinearity issues...
# 21                                          Not Taken
# 22   Errors have constant variance (homoscedasticity)
# 23                                          Not Taken
# 24  There are significant multicollinearity issues...
# 25                                          Not Taken
# 26                                          Not Taken
# 27                                          Not Taken
# 28                                          Not Taken
# 29  There are significant multicollinearity issues...
# 30                                          Not Taken
#
#                                                   MQ3  \
# 0                                           Not Taken
# 1   The model is violating the assumption of linea...
# 2                                           Not Taken
# 3                                           Not Taken
# 4                                           Not Taken
# 5   The model is violating the assumption of linea...
# 6                                           Not Taken
# 7                                           Not Taken
# 8   The model is violating the assumption of linea...
# 9   The model is violating the assumption of linea...
# 10                                          Not Taken
# 11  The model is violating the assumption of linea...
# 12  The model is violating the assumption of linea...
# 13                                          Not Taken
# 14                                          Not Taken
# 15                                          Not Taken
# 16                                          Not Taken
# 17                                          Not Taken
# 18  The model is violating the assumption of linea...
# 19  The model is violating the assumption of linea...
# 20  The model is violating the assumption of linea...
# 21                                          Not Taken
# 22  The model is violating the assumption of linea...
# 23                                          Not Taken
# 24          The model has high bias and high variance
# 25                                          Not Taken
# 26                                          Not Taken
# 27                                          Not Taken
# 28                                          Not Taken
# 29            The model is fitting the data perfectly
# 30                                          Not Taken
#
#                                                   MQ4  \
# 0                                           Not Taken
# 1   The true population parameter lies within the ...
# 2                                           Not Taken
# 3                                           Not Taken
# 4                                           Not Taken
# 5   The interval contains the true population para...
# 6                                           Not Taken
# 7                                           Not Taken
# 8   The true population parameter lies within the ...
# 9   The true population parameter lies within the ...
# 10                                          Not Taken
# 11  There is a 95% chance that the sample mean is ...
# 12  There is a 95% chance that the sample mean is ...
# 13                                          Not Taken
# 14                                          Not Taken
# 15                                          Not Taken
# 16                                          Not Taken
# 17                                          Not Taken
# 18  The true population parameter lies within the ...
# 19  The interval contains the true population para...
# 20  The interval contains the true population para...
# 21                                          Not Taken
# 22  The interval contains the true population para...
# 23                                          Not Taken
# 24  There is a 95% chance that the sample mean is ...
# 25                                          Not Taken
# 26                                          Not Taken
# 27                                          Not Taken
# 28                                          Not Taken
# 29  The interval contains the true population para...
# 30                                          Not Taken
#
#                                                   MQ5
# 0                                           Not Taken
# 1   The model is too simple to capture the data's ...
# 2                                           Not Taken
# 3                                           Not Taken
# 4                                           Not Taken
# 5   The model is too simple to capture the data's ...
# 6                                           Not Taken
# 7                                           Not Taken
# 8   The model is too simple to capture the data's ...
# 9   The model is too simple to capture the data's ...
# 10                                          Not Taken
# 11  The model is too simple to capture the data's ...
# 12  The model is too simple to capture the data's ...
# 13                                          Not Taken
# 14                                          Not Taken
# 15                                          Not Taken
# 16                                          Not Taken
# 17                                          Not Taken
# 18  The model is too simple to capture the data's ...
# 19  The model is overly complex and fits the noise...
# 20  The model is too simple to capture the data's ...
# 21                                          Not Taken
# 22  The model is too simple to capture the data's ...
# 23                                          Not Taken
# 24  The model is too simple to capture the data's ...
# 25                                          Not Taken
# 26                                          Not Taken
# 27                                          Not Taken
# 28                                          Not Taken
# 29  The model is too simple to capture the data's ...
# 30                                          Not Taken
#
# [31 rows x 34 columns]

# %% [markdown]
# ### __Public Domain Data__

# %%
with open('./supplemental_material/coded_en.csv', 'rb') as f:
    result = chardet.detect(f.read())
    print(result)
# Out:
# {'encoding': 'windows-1251', 'confidence': 0.936604085794506, 'language': 'Bulgarian'}

# %%
coded_en_df = pd.read_csv('./supplemental_material/coded_en.csv', encoding='windows-1251', delimiter=';')
coded_en_df.fillna('No Response', inplace=True)

# %%
coded_en_df
# Out:
#               Timestamp  Q1                                 Q2  Q3  Q4  Q5.1  \
# 0    5.14.2023 21:22:19   2   International Economic Relations   1   4     4
# 1     5.15.2023 8:45:52   1  International Economic Relations    1   3     2
# 2     5.15.2023 9:54:15   1   International Economic Relations   1   2     3
# 3    5.15.2023 15:17:41   1   International Economic Relations   1   2     4
# 4    5.15.2023 15:19:02   1   International Economic Relations   1   3     4
# ..                  ...  ..                                ...  ..  ..   ...
# 126  5.26.2023 15:44:55   1   International Economic Relations   1   4     4
# 127  5.26.2023 21:43:23   1                           Finance    1   1     3
# 128  5.27.2023 10:28:36   1                          Marketing   1   5     4
# 129   5.28.2023 0:51:54   1              Public Administration   2   4     4
# 130  5.31.2023 17:42:52   1                            Finance   1   2     3
#
#      Q5.2  Q5.3  Q5.4  Q5.5  ...  Q8.2  Q8.3  Q8.4  Q8.5  Q9.1  Q9.2  Q9.3  \
# 0       4     5     5     4  ...     5     5     4     5     4     5     5
# 1       4     2     1     3  ...     4     4     2     3     3     4     3
# 2       3     3     2     3  ...     4     4     3     3     3     3     2
# 3       4     4     2     4  ...     4     4     4     4     4     4     3
# 4       4     3     2     4  ...     4     4     3     3     3     3     3
# ..    ...   ...   ...   ...  ...   ...   ...   ...   ...   ...   ...   ...
# 126     3     4     4     4  ...     4     4     2     3     3     4     3
# 127     3     2     2     3  ...     4     4     4     4     4     4     4
# 128     4     3     3     3  ...     5     5     4     4     2     4     3
# 129     4     4     4     3  ...     4     4     4     4     2     3     3
# 130     3     3     3     3  ...     3     3     3     3     3     3     3
#
#      Q9.4  Q9.5                                                Q10
# 0       4     4                                        No Response
# 1       2     2                                        No Response
# 2       2     3                                        No Response
# 3       4     4                                        No Response
# 4       3     3                                        No Response
# ..    ...   ...                                                ...
# 126     4     4  ChtGPT helps me a lot in preparing for assignm...
# 127     4     4                                        No Response
# 128     4     4                                        No Response
# 129     3     3                                        No Response
# 130     3     3                                   I don't have any
#
# [131 rows x 34 columns]

# %% [markdown]
# ### __PandasGUI__

# %%
show(responses_df)
# Out:
# PandasGUI INFO — pandasgui.gui — Opening PandasGUI
